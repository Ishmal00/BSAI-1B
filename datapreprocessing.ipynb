# %% [markdown]
# #### Submitted by Ishmal Nadeem (101)

# %% [markdown]
# ### Pandas
# Pandas is a powerful data analysis library in Python. It provides data structures and functions.
# Steps for data analysis with pandas:
# 1. Import pandas library
# 2. Pip install pandas

# %% [markdown]
# #### a. Data Load
# Load your dataset using Python:

# %%
import pandas as pd
import numpy as np  
df=DataFrame=pd.read_csv("onlinefoods.csv")

# %% [markdown]
# #### b. Explore data set
# - Shape
# - Checking rows and column
# - Basic info and statistics
# -

# %%
type(df)
df.head() #df.tail()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
df.shape
# (rows,column)
# Out:
# (388, 13)

# %%
df.info(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
#  12  Unnamed: 12                 388 non-null    object
# ...

# %%
# df.head(4)
df.tail(3)
# df.sample(3)
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output  Feedback Unnamed: 12
# 385    Yes  Positive         Yes
# 386    Yes  Positive         Yes
# 387    Yes  Positive         Yes

# %% [markdown]
# #### c. Data Cleaning
# In this step, we handle missing values, duplicates, and irrelevant data.

# %%
# Python Code for Data Cleaning
print(df.isnull().sum())
df.fillna(0, inplace=True)
df.drop_duplicates(inplace=True)
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %% [markdown]
# #### Cleaning empty set

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of      Age  Gender Marital Status Occupation   Monthly Income  \
# 0     20  Female         Single    Student        No Income
# 1     24  Female         Single    Student   Below Rs.10000
# 2     22    Male         Single    Student   Below Rs.10000
# 3     22  Female         Single    Student        No Income
# 4     22    Male         Single    Student   Below Rs.10000
# ..   ...     ...            ...        ...              ...
# 355   21    Male         Single    Student        No Income
# 363   31    Male        Married   Employee  More than 50000
# 369   30    Male        Married   Employee  More than 50000
# 374   21    Male         Single    Student        No Income
# 386   23    Male         Single    Student   Below Rs.10000
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# ...

# %%
df.dropna(inplace=True)

# %% [markdown]
# #### Data Duplications

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 355    False
# 363    False
# 369    False
# 374    False
# 386    False
# Length: 285, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      Age  Gender Marital Status Occupation   Monthly Income  \
# 0     20  Female         Single    Student        No Income
# 1     24  Female         Single    Student   Below Rs.10000
# 2     22    Male         Single    Student   Below Rs.10000
# 3     22  Female         Single    Student        No Income
# 4     22    Male         Single    Student   Below Rs.10000
# ..   ...     ...            ...        ...              ...
# 355   21    Male         Single    Student        No Income
# 363   31    Male        Married   Employee  More than 50000
# 369   30    Male        Married   Employee  More than 50000
# 374   21    Male         Single    Student        No Income
# 386   23    Male         Single    Student   Below Rs.10000
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
# Statistical Analysis
df.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  285.000000   285.000000  285.000000  285.000000     285.000000
# mean    24.677193     3.270175   12.973429   77.597593  560037.280702
# std      3.040977     1.361178    0.043964    0.053557      30.738306
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.943800   77.563500  560010.000000
# 50%     24.000000     3.000000   12.977000   77.587700  560028.000000
# 75%     26.000000     4.000000   12.998000   77.622700  560066.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
df.describe(include = "all").iloc[[0,6]]
# Out:
#          Age Gender Marital Status Occupation Monthly Income  \
# count  285.0    285            285        285            285
# min     18.0    NaN            NaN        NaN            NaN
#
#       Educational Qualifications  Family size  latitude  longitude  Pin code  \
# count                        285        285.0  285.0000   285.0000     285.0
# min                          NaN          1.0   12.8652    77.4842  560001.0
#
#       Output Feedback Unnamed: 12
# count    285      285         285
# min      NaN      NaN         NaN

# %%
df.describe(include = "all").loc[["min","max"]]
# Out:
#       Age Gender Marital Status Occupation Monthly Income  \
# min  18.0    NaN            NaN        NaN            NaN
# max  33.0    NaN            NaN        NaN            NaN
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# min                        NaN          1.0   12.8652    77.4842  560001.0
# max                        NaN          6.0   13.1020    77.7582  560109.0
#
#     Output Feedback Unnamed: 12
# min    NaN      NaN         NaN
# max    NaN      NaN         NaN

# %% [markdown]
# #### d. DATA PreProcessing

# %% [markdown]
# ## Adding a column

# %%
df['col'] = 4
df
# Out:
#      Age  Gender Marital Status Occupation   Monthly Income  \
# 0     20  Female         Single    Student        No Income
# 1     24  Female         Single    Student   Below Rs.10000
# 2     22    Male         Single    Student   Below Rs.10000
# 3     22  Female         Single    Student        No Income
# 4     22    Male         Single    Student   Below Rs.10000
# ..   ...     ...            ...        ...              ...
# 355   21    Male         Single    Student        No Income
# 363   31    Male        Married   Employee  More than 50000
# 369   30    Male        Married   Employee  More than 50000
# 374   21    Male         Single    Student        No Income
# 386   23    Male         Single    Student   Below Rs.10000
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %% [markdown]
# #### Remove a column

# %%
df.drop(columns=['col'], inplace=True, errors='ignore')
df
# Out:
#      Age  Gender Marital Status Occupation   Monthly Income  \
# 0     20  Female         Single    Student        No Income
# 1     24  Female         Single    Student   Below Rs.10000
# 2     22    Male         Single    Student   Below Rs.10000
# 3     22  Female         Single    Student        No Income
# 4     22    Male         Single    Student   Below Rs.10000
# ..   ...     ...            ...        ...              ...
# 355   21    Male         Single    Student        No Income
# 363   31    Male        Married   Employee  More than 50000
# 369   30    Male        Married   Employee  More than 50000
# 374   21    Male         Single    Student        No Income
# 386   23    Male         Single    Student   Below Rs.10000
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %% [markdown]
# #### Adding a row

# %%
a = {
    'Name': 'New GPU',  
    'Wattage': 200,           
    'VRAM': 12,              
    '3DMARK': 15000,          
}

df = pd.concat([df, pd.DataFrame([a])], ignore_index=True)
df
# Out:
#       Age  Gender Marital Status Occupation   Monthly Income  \
# 0    20.0  Female         Single    Student        No Income
# 1    24.0  Female         Single    Student   Below Rs.10000
# 2    22.0    Male         Single    Student   Below Rs.10000
# 3    22.0  Female         Single    Student        No Income
# 4    22.0    Male         Single    Student   Below Rs.10000
# ..    ...     ...            ...        ...              ...
# 281  31.0    Male        Married   Employee  More than 50000
# 282  30.0    Male        Married   Employee  More than 50000
# 283  21.0    Male         Single    Student        No Income
# 284  23.0    Male         Single    Student   Below Rs.10000
# 285   NaN     NaN            NaN        NaN              NaN
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate          4.0   12.9766    77.5993  560001.0
# 1                     Graduate          3.0   12.9770    77.5773  560009.0
# ...

# %% [markdown]
# #### Remove a row

# %%
df.drop(50,inplace=True) 
df
# Out:
#       Age  Gender Marital Status Occupation   Monthly Income  \
# 0    20.0  Female         Single    Student        No Income
# 1    24.0  Female         Single    Student   Below Rs.10000
# 2    22.0    Male         Single    Student   Below Rs.10000
# 3    22.0  Female         Single    Student        No Income
# 4    22.0    Male         Single    Student   Below Rs.10000
# ..    ...     ...            ...        ...              ...
# 281  31.0    Male        Married   Employee  More than 50000
# 282  30.0    Male        Married   Employee  More than 50000
# 283  21.0    Male         Single    Student        No Income
# 284  23.0    Male         Single    Student   Below Rs.10000
# 285   NaN     NaN            NaN        NaN              NaN
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate          4.0   12.9766    77.5993  560001.0
# 1                     Graduate          3.0   12.9770    77.5773  560009.0
# ...

# %%
df.head(2)
#for permanent name change:
# df.rename(columns={"body-style": "body"},inplace=True)
# Out:
#     Age  Gender Marital Status Occupation  Monthly Income  \
# 0  20.0  Female         Single    Student       No Income
# 1  24.0  Female         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate          4.0   12.9766    77.5993  560001.0
# 1                   Graduate          3.0   12.9770    77.5773  560009.0
#
#   Output  Feedback Unnamed: 12 Name  Wattage  VRAM  3DMARK
# 0    Yes  Positive         Yes  NaN      NaN   NaN     NaN
# 1    Yes  Positive         Yes  NaN      NaN   NaN     NaN

# %% [markdown]
# #### Data Visualization

# %%
b= DataFrame = df[["Occupation","Marital Status"]]
b.head(5)
# Out:
#   Occupation Marital Status
# 0    Student         Single
# 1    Student         Single
# 2    Student         Single
# 3    Student         Single
# 4    Student         Single

# %%
df["Occupation"]. value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df["Marital Status"]. value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Age"]. value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Educational Qualifications"]. value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Educational Qualifications'>

# %%
df["latitude"].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# 4. **Data Augmentation**

# %%
df['Family_Size_Category']=df['Family size'].apply(lambda x: 'Small' if x<=3 else'Large')

# %% [markdown]
# #### Replace Empty values

# %%
df.fillna(17)
# Out:
#       Age  Gender Marital Status Occupation   Monthly Income  \
# 0    20.0  Female         Single    Student        No Income
# 1    24.0  Female         Single    Student   Below Rs.10000
# 2    22.0    Male         Single    Student   Below Rs.10000
# 3    22.0  Female         Single    Student        No Income
# 4    22.0    Male         Single    Student   Below Rs.10000
# ..    ...     ...            ...        ...              ...
# 281  31.0    Male        Married   Employee  More than 50000
# 282  30.0    Male        Married   Employee  More than 50000
# 283  21.0    Male         Single    Student        No Income
# 284  23.0    Male         Single    Student   Below Rs.10000
# 285  17.0      17             17         17               17
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate          4.0   12.9766    77.5993  560001.0
# 1                     Graduate          3.0   12.9770    77.5773  560009.0
# ...

# %%
df["latitude"].mode()
# Out:
# 0    12.977
# Name: latitude, dtype: float64

# %%
df["longitude"].median()
# Out:
# 77.5877

# %%
df["latitude"].mean()
# Out:
# 12.973579929577465

# %% [markdown]
# #### Slicing

# %%
df[1:7]
# Out:
#     Age  Gender Marital Status Occupation   Monthly Income  \
# 1  24.0  Female         Single    Student   Below Rs.10000
# 2  22.0    Male         Single    Student   Below Rs.10000
# 3  22.0  Female         Single    Student        No Income
# 4  22.0    Male         Single    Student   Below Rs.10000
# 5  27.0  Female        Married   Employee  More than 50000
# 6  22.0    Male         Single    Student        No Income
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 1                   Graduate          3.0   12.9770    77.5773  560009.0
# 2              Post Graduate          3.0   12.9551    77.6593  560017.0
# 3                   Graduate          6.0   12.9473    77.5616  560019.0
# 4              Post Graduate          4.0   12.9850    77.5533  560010.0
# 5              Post Graduate          2.0   12.9299    77.6848  560103.0
# 6                   Graduate          3.0   12.9770    77.5773  560009.0
#
# ...

# %%
df[2:20:3]
# Out:
#      Age  Gender Marital Status      Occupation   Monthly Income  \
# 2   22.0    Male         Single         Student   Below Rs.10000
# 5   27.0  Female        Married        Employee  More than 50000
# 8   23.0  Female         Single         Student        No Income
# 11  23.0    Male         Single         Student   Below Rs.10000
# 14  23.0  Female         Single  Self Employeed   10001 to 25000
# 17  23.0  Female         Single         Student        No Income
#
#    Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 2               Post Graduate          3.0   12.9551    77.6593  560017.0
# 5               Post Graduate          2.0   12.9299    77.6848  560103.0
# 8               Post Graduate          2.0   12.9766    77.5993  560001.0
# 11              Post Graduate          2.0   12.9770    77.5773  560009.0
# 14              Post Graduate          5.0   12.9438    77.5738  560004.0
# ...

# %% [markdown]
# #### Data Saving

# %%
df.to_excel("gpu_data.xlsx", index=False, engine='openpyxl')
